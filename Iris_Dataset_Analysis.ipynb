# %%
# Install libraries (only run once)
# !pip install pandas matplotlib seaborn scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 2.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/11.1 MB 2.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/11.1 MB 2.4 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.1 MB 2.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/11.1 MB 2.6 MB/s eta 0:00:04
#    ------------ --------------------------- 3.4/11.1 MB 2.6 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/11.1 MB 2.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/11.1 MB 2.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.1 MB 2.6 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.1 MB 2.6 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.1 MB 2.6 MB/s eta 0:00:02
# ...

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()

# Create a DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Add target column (species)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# Show first few rows
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Check Data Types
print(df.dtypes)

# Check for missing values
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# sepal length (cm)     float64
# sepal width (cm)      float64
# petal length (cm)     float64
# petal width (cm)      float64
# species              category
# dtype: object
#
# Missing Values:
#  sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
# Summary statistics
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Group by species and calculate mean of each feature
grouped_means = df.groupby('species').mean()
grouped_means
# Out:
# C:\Users\onale\AppData\Local\Temp\ipykernel_33052\421607481.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_means = df.groupby('species').mean()
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026

# %%
# Observations:
- Setosa has the smallest petal length and width.
- Virginica has the largest petal and sepal sizes.
- Petal length and width seem to vary much more between species than sepal size.
# Out:
#   Cell In[6], line 2
#     - Setosa has the smallest petal length and width.
#              ^
# SyntaxError: invalid syntax

# %%
# Line plot of sepal length across samples
plt.figure(figsize=(10,6))
plt.plot(df.index, df['sepal length (cm)'], label='Sepal Length')
plt.title('Sepal Length across Samples')
plt.xlabel('Sample Index')
plt.ylabel('Sepal Length (cm)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Bar plot
plt.figure(figsize=(8,5))
sns.barplot(x=grouped_means.index, y=grouped_means['petal length (cm)'])
plt.title('Average Petal Length per Species')
plt.xlabel('Species')
plt.ylabel('Average Petal Length (cm)')
plt.show()

# %%
# Histogram
plt.figure(figsize=(8,5))
sns.histplot(df['petal length (cm)'], bins=20, kde=True)
plt.title('Distribution of Petal Length')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter plot
plt.figure(figsize=(8,5))
sns.scatterplot(x='sepal length (cm)', y='petal length (cm)', hue='species', data=df)
plt.title('Sepal Length vs Petal Length by Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend()
plt.show()

# %%
from sklearn.datasets import load_iris

# Using try-except to catch errors when loading the dataset
try:
    iris = load_iris()
    print("Dataset loaded successfully")
except Exception as e:
    print("Error loading the dataset:", e)
# Out:
# Dataset loaded successfully
